# %% [markdown]
# # Population vs. Median Home Prices
# #### *Linear Regression with Single Variable*

# %% [markdown]
# *Note, this notebook requires Spark 2.0+*

# %%
# %scala if (org.apache.spark.BuildInfo.sparkBranch < "2.0") sys.error("Attach this notebook to a cluster running Spark 2.0+")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Load and parse the data

# %%
# Use the Spark CSV datasource with options specifying:
#  - First line of file is a header
#  - Automatically infer the schema of the data
#  - Note that we're using `spark` instead of `sqlContext` now.
data = spark.read.format("com.databricks.spark.csv")\
  .option("header", "true")\
  .option("inferSchema", "true")\
  .load("/databricks-datasets/samples/population-vs-price/data_geo.csv")
data.cache()  # Cache data for faster reuse
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>294
# </div>

# %%
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>2014 rank</th><th>City</th><th>State</th><th>State Code</th><th>2014 Population estimate</th><th>2015 median sales price</th></tr></thead><tbody><tr><td>101.0</td><td>Birmingham</td><td>Alabama</td><td>AL</td><td>212247.0</td><td>162.9</td></tr><tr><td>125.0</td><td>Huntsville</td><td>Alabama</td><td>AL</td><td>188226.0</td><td>157.7</td></tr><tr><td>122.0</td><td>Mobile</td><td>Alabama</td><td>AL</td><td>194675.0</td><td>122.5</td></tr><tr><td>114.0</td><td>Montgomery</td><td>Alabama</td><td>AL</td><td>200481.0</td><td>129.0</td></tr><tr><td>64.0</td><td>Anchorage[19]</td><td>Alaska</td><td>AK</td><td>301010.0</td><td>null</td></tr><tr><td>78.0</td><td>Chandler</td><td>Arizona</td><td>AZ</td><td>254276.0</td><td>null</td></tr><tr><td>86.0</td><td>Gilbert[20]</td><td>Arizona</td><td>AZ</td><td>239277.0</td><td>null</td></tr><tr><td>88.0</td><td>Glendale</td><td>Arizona</td><td>AZ</td><td>237517.0</td><td>null</td></tr><tr><td>38.0</td><td>Mesa</td><td>Arizona</td><td>AZ</td><td>464704.0</td><td>null</td></tr><tr><td>148.0</td><td>Peoria</td><td>Arizona</td><td>AZ</td><td>166934.0</td><td>null</td></tr><tr><td>6.0</td><td>Phoenix</td><td>Arizona</td><td>AZ</td><td>1537058.0</td><td>206.1</td></tr><tr><td>95.0</td><td>Scottsdale</td><td>Arizona</td><td>AZ</td><td>230512.0</td><td>null</td></tr><tr><td>215.0</td><td>Surprise</td><td>Arizona</td><td>AZ</td><td>126275.0</td><td>null</td></tr><tr><td>142.0</td><td>Tempe</td><td>Arizona</td><td>AZ</td><td>172816.0</td><td>null</td></tr><tr><td>33.0</td><td>Tucson</td><td>Arizona</td><td>AZ</td><td>527972.0</td><td>178.1</td></tr><tr><td>119.0</td><td>Little Rock</td><td>Arkansas</td><td>AR</td><td>197706.0</td><td>131.8</td></tr><tr><td>56.0</td><td>Anaheim</td><td>California</td><td>CA</td><td>346997.0</td><td>685.7</td></tr><tr><td>261.0</td><td>Antioch</td><td>California</td><td>CA</td><td>108930.0</td><td>null</td></tr><tr><td>52.0</td><td>Bakersfield</td><td>California</td><td>CA</td><td>368759.0</td><td>null</td></tr><tr><td>227.0</td><td>Berkeley</td><td>California</td><td>CA</td><td>118853.0</td><td>null</td></tr><tr><td>276.0</td><td>Burbank</td><td>California</td><td>CA</td><td>105368.0</td><td>null</td></tr><tr><td>245.0</td><td>Carlsbad</td><td>California</td><td>CA</td><td>112299.0</td><td>null</td></tr><tr><td>75.0</td><td>Chula Vista</td><td>California</td><td>CA</td><td>260988.0</td><td>null</td></tr><tr><td>291.0</td><td>Clovis</td><td>California</td><td>CA</td><td>102189.0</td><td>null</td></tr><tr><td>212.0</td><td>Concord</td><td>California</td><td>CA</td><td>127522.0</td><td>null</td></tr><tr><td>153.0</td><td>Corona</td><td>California</td><td>CA</td><td>161486.0</td><td>null</td></tr><tr><td>243.0</td><td>Costa Mesa</td><td>California</td><td>CA</td><td>112784.0</td><td>null</td></tr><tr><td>274.0</td><td>Daly City</td><td>California</td><td>CA</td><td>106094.0</td><td>null</td></tr><tr><td>240.0</td><td>Downey</td><td>California</td><td>CA</td><td>114172.0</td><td>null</td></tr><tr><td>285.0</td><td>El Cajon</td><td>California</td><td>CA</td><td>103091.0</td><td>null</td></tr><tr><td>234.0</td><td>El Monte</td><td>California</td><td>CA</td><td>116631.0</td><td>null</td></tr><tr><td>151.0</td><td>Elk Grove</td><td>California</td><td>CA</td><td>163553.0</td><td>null</td></tr><tr><td>167.0</td><td>Escondido</td><td>California</td><td>CA</td><td>150243.0</td><td>null</td></tr><tr><td>250.0</td><td>Fairfield</td><td>California</td><td>CA</td><td>111125.0</td><td>null</td></tr><tr><td>108.0</td><td>Fontana</td><td>California</td><td>CA</td><td>204950.0</td><td>null</td></tr><tr><td>97.0</td><td>Fremont</td><td>California</td><td>CA</td><td>228758.0</td><td>null</td></tr><tr><td>34.0</td><td>Fresno</td><td>California</td><td>CA</td><td>515986.0</td><td>null</td></tr><tr><td>186.0</td><td>Fullerton</td><td>California</td><td>CA</td><td>139677.0</td><td ...

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- 2014 rank: integer (nullable = true)
# -- City: string (nullable = true)
# -- State: string (nullable = true)
# -- State Code: string (nullable = true)
# -- 2014 Population estimate: integer (nullable = true)
# -- 2015 median sales price: double (nullable = true)
#
# </div>

# %%
data = data.dropna()  # drop rows with missing values
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>109
# </div>

# %%
# This will let us access the table from our SQL notebook!
#  Note - we're using `createOrReplaceTempView` instead of `registerTempTable`
data.createOrReplaceTempView("data_geo")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select City, `State Code`, `2014 Population estimate`/1000 as `2014 Pop estimate`, `2015 median sales price` from data_geo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City</th><th>State Code</th><th>2014 Pop estimate</th><th>2015 median sales price</th></tr></thead><tbody><tr><td>Birmingham</td><td>AL</td><td>212.247</td><td>162.9</td></tr><tr><td>Huntsville</td><td>AL</td><td>188.226</td><td>157.7</td></tr><tr><td>Mobile</td><td>AL</td><td>194.675</td><td>122.5</td></tr><tr><td>Montgomery</td><td>AL</td><td>200.481</td><td>129.0</td></tr><tr><td>Phoenix</td><td>AZ</td><td>1537.058</td><td>206.1</td></tr><tr><td>Tucson</td><td>AZ</td><td>527.972</td><td>178.1</td></tr><tr><td>Little Rock</td><td>AR</td><td>197.706</td><td>131.8</td></tr><tr><td>Anaheim</td><td>CA</td><td>346.997</td><td>685.7</td></tr><tr><td>Los Angeles</td><td>CA</td><td>3928.864</td><td>434.7</td></tr><tr><td>Riverside</td><td>CA</td><td>319.504</td><td>281.0</td></tr><tr><td>Sacramento</td><td>CA</td><td>485.199</td><td>275.8</td></tr><tr><td>San
800.0</td><td>153.0</td></tr><tr><td>165378.0</td><td>116.5</td></tr><tr><td>272996.0</td><td>150.2</td></tr><tr><td>446599.0</td><td>148.1</td></tr><tr><td>613599.0</td><td>205.9</td></tr><tr><td>236995.0</td><td>268.7</td></tr><tr><td>110448.0</td><td>237.4</td></tr><tr><td>280579.0</td><td>350.8</td></tr><tr><td>557169.0</td><td>172.2</td></tr><tr><td>258703.0</td><td>117.3</td></tr><tr><td>8491079.0</td><td>388.6</td></tr><tr><td>209983.0</td><td>118.9</td></tr><tr><td>144263.0</td><td>118.3</td></tr><tr><td>809958.0</td><td>197.2</td></tr><tr><td>251893.0</td><td>196.9</td></tr><tr><td>203948.0</td><td>145.0</td></tr><tr><td>282586.0</td><td>138.3</td></tr><tr><td>439896.0</td><td>218.9</td></tr><tr><td>113657.0</td><td>197.5</td></tr><tr><td>239269.0</td><td>138.6</td></tr><tr><td>115863.0</td><td>180.0</td></tr><tr><td>197859.0</td><td>95.4</td></tr><tr><td>298165.0</td><td>135.0</td></tr><tr><td>389521.0</td><td>105.9</td></tr><tr><td>835957.0</td><td>149.9</td></tr><tr><td>141003.0</td><td>107.2</td></tr><tr><td>281031.0</td><td>83.8</td></tr><tr><td>399682.0</td><td>145.1</td></tr><tr><td>160561.0</td><td>211.3</td></tr><tr><td>619360.0</td><td>289.4</td></tr><tr><td>161637.0</td><td>193.9</td></tr><tr><td>119104.0</td><td>162.7</td></tr><tr><td>1560297.0</td><td>204.9</td></tr><tr><td>179154.0</td><td>233.3</td></tr><tr><td>168586.0</td><td>159.5</td></tr><tr><td>173778.0</td><td>143.6</td></tr><tr><td>184281.0</td><td>149.2</td></tr><tr><td>656861.0</td><td>132.1</td></tr><tr><td>644014.0</td><td>186.4</td></tr><tr><td>120958.0</td><td>145.7</td></tr><tr><td>197254.0</td><td>144.4</td></tr><tr><td>912791 ...

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=["2014 Population estimate"],
    outputCol="features")
output = assembler.transform(df)
display(output.select("features", "label"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>label</th></tr></thead><tbody><tr><td>List(1.0, 1.0, List(), List(212247.0))</td><td>162.9</td></tr><tr><td>List(1.0, 1.0, List(), List(188226.0))</td><td>157.7</td></tr><tr><td>List(1.0, 1.0, List(), List(194675.0))</td><td>122.5</td></tr><tr><td>List(1.0, 1.0, List(), List(200481.0))</td><td>129.0</td></tr><tr><td>List(1.0, 1.0, List(), List(1537058.0))</td><td>206.1</td></tr><tr><td>List(1.0, 1.0, List(), List(527972.0))</td><td>178.1</td></tr><tr><td>List(1.0, 1.0, List(), List(197706.0))</td><td>131.8</td></tr><tr><td>List(1.0, 1.0, List(), List(346997.0))</td><td>685.7</td></tr><tr><td>List(1.0, 1.0, List(), List(3928864.0))</td><td>434.7</td></tr><tr><td>List(1.0, 1.0, List(), List(319504.0))</td><td>281.0</td></tr><tr><td>List(1.0, 1.0, List(), List(485199.0))</td><td>275.8</td></tr><tr><td>List(1.0, 1.0, List(), List(1381069.0))</td><td>510.3</td></tr><tr><td>List(1.0, 1.0, List(), List(852469.0))</td><td>748.3</td></tr><tr><td>List(1.0, 1.0, List(), List(1015785.0))</td><td>900.0</td></tr><tr><td>List(1.0, 1.0, List(), List(105112.0))</td><td>442.2</td></tr><tr><td>List(1.0, 1.0, List(), List(445830.0))</td><td>220.1</td></tr><tr><td>List(1.0, 1.0, List(), List(663862.0))</td><td>338.1</td></tr><tr><td>List(1.0, 1.0, List(), List(147612.0))</td><td>342.7</td></tr><tr><td>List(1.0, 1.0, List(), List(124705.0))</td><td>202.6</td></tr><tr><td>List(1.0, 1.0, List(), List(130282.0))</td><td>205.1</td></tr><tr><td>List(1.0, 1.0, List(), List(658893.0))</td><td>367.8</td></tr><tr><td>List(1.0, 1.0, List(), List(169854.0))</td><td>208.0</td></tr><tr><td>List(1.0, 1.0, List(), List(128460.0))</td><td>169.9</td></tr><tr><td>List(1.0, 1.0, List(), List(853382.0))</td><td>182.5</td></tr><tr><td>List(1.0, 1.0, List(), List(102346.0))</td><td>136.0</td></tr><tr><td>List(1.0, 1.0, List(), List(430332.0))</td><td>269.1</td></tr><tr><td>List(1.0, 1.0, List(), List(105838.0))</td><td>145.0</td></tr><tr><td>List(1.0, 1.0, List(), List(174110.0))</td><td>172.0</td></tr><tr><td>List(1.0, 1.0, List(), List(188107.0))</td><td>170.5</td></tr><tr><td>List(1.0, 1.0, List(), List(358699.0))</td><td>156.0</td></tr><tr><td>List(1.0, 1.0, List(), List(456002.0))</td><td>158.0</td></tr><tr><td>List(1.0, 1.0, List(), List(350399.0))</td><td>699.3</td></tr><tr><td>List(1.0, 1.0, List(), List(216282.0))</td><td>178.7</td></tr><tr><td>List(1.0, 1.0, List(), List(2722389.0))</td><td>192.5</td></tr><tr><td>List(1.0, 1.0, List(), List(115828.0))</td><td>105.2</td></tr><tr><td>List(1.0, 1.0, List(), List(149123.0))</td><td>78.6</td></tr><tr><td>List(1.0, 1.0, List(), List(116809.0))</td><td>115.2</td></tr><tr><td>List(1.0, 1.0, List(), List(258522.0))</td><td>106.3</td></tr><tr><td>List(1.0, 1.0, List(), List(848788.0))</td><td>139.2</td></tr><tr><td>List(1.0, 1.0, List(), List(129195.0))</td><td>156.9</td></tr><tr><td>List(1.0, 1.0, List(), List(102448.0))</td><td>109.4</td></tr><tr><td>List(1.0, 1.0, List(), List(127215.0))</td><td>105.3</td></tr><tr><td>List(1.0, 1.0, List(), List(388413.0))</td><td>126.0</td></tr><tr><td>List(1.0, 1.0, List(), List(310797.0))</td><td>141.2</td></tr><tr><td>List(1.0, 1.0, List(), List(612780.0))</td><td>141.1</td></tr><tr><td>List(1.0, 1.0, List(), List(228895.0))</td><td>177.2</td></tr><tr><td>List(1.0, 1.0, List(), List(198242.0))</td><td>151.6</td></tr><tr><td>List(1.0, 1.0, List(), List(622793.0))</td><td>223.1</td></tr><tr><td>List(1.0, 1.0, List(), List(655884.0))</td><td>374.6</td></tr><tr><td>List(1.0, 1.0, List(), List(153991.0))</td><td>183.9</td></tr><tr><td>List(1.0, 1.0, List(), List(183016.0))</td><td>226.9</td></tr><tr><td>List(1.0, 1.0, List(), List(114620.0))</td><td>114.6</td></tr><tr><td>List(1.0, 1.0, List(), List(407207.0))</td><td>209.4</td></tr><tr><td>List(1.0, 1.0, List(), List(171155.0))</td><td>154.1</td></tr><tr><td>List(1.0, 1.0, List(), List(470800.0))</td ...

# %% [markdown]
# ## Linear Regression
#
# **Goal**
# * Predict y = 2015 Median Housing Price
# * Using feature x = 2014 Population Estimate
#
# **References**
# * [MLlib LinearRegression user guide](http://spark.apache.org/docs/latest/ml-classification-regression.html#linear-regression)
# * [PySpark LinearRegression API](http://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.regression.LinearRegression)

# %%
# Import LinearRegression class
from pyspark.ml.regression import LinearRegression

# Define LinearRegression algorithm
lr = LinearRegression()

# Fit 2 models, using different regularization parameters
modelA = lr.fit(output, {lr.regParam:0.0})
modelB = lr.fit(output, {lr.regParam:100.0})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print ">>>> ModelA intercept: %r, coefficient: %r" % (modelA.intercept, modelA.coefficients[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&gt;&gt;&gt;&gt; ModelA intercept: 191.29427575139397, coefficient: 3.7797896823382454e-05
# </div>

# %%
print ">>>> ModelB intercept: %r, coefficient: %r" % (modelB.intercept, modelB.coefficients[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&gt;&gt;&gt;&gt; ModelB intercept: 199.8511256466715, coefficient: 2.1603499483717156e-05
# </div>

# %% [markdown]
# ## Make predictions
#
# Calling `transform()` on data adds a new column of predictions.

# %%
# Make predictions
predictionsA = modelA.transform(output)
display(predictionsA)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>2014 Population estimate</th><th>label</th><th>features</th><th>prediction</th></tr></thead><tbody><tr><td>212247.0</td><td>162.9</td><td>List(1.0, 1.0, List(), List(212247.0))</td><td>199.31676595846642</td></tr><tr><td>188226.0</td><td>157.7</td><td>List(1.0, 1.0, List(), List(188226.0))</td><td>198.40882267887196</td></tr><tr><td>194675.0</td><td>122.5</td><td>List(1.0, 1.0, List(), List(194675.0))</td><td>198.65258131548595</td></tr><tr><td>200481.0</td><td>129.0</td><td>List(1.0, 1.0, List(), List(200481.0))</td><td>198.8720359044425</td></tr><tr><td>1537058.0</td><td>206.1</td><td>List(1.0, 1.0, List(), List(1537058.0))</td><td>249.39183544694856</td></tr><tr><td>527972.0</td><td>178.1</td><td>List(1.0, 1.0, List(), List(527972.0))</td><td>211.25050693302884</td></tr><tr><td>197706.0</td><td>131.8</td><td>List(1.0, 1.0, List(), List(197706.0))</td><td>198.76714674075762</td></tr><tr><td>346997.0</td><td>685.7</td><td>List(1.0, 1.0, List(), List(346997.0))</td><td>204.41003255541722</td></tr><tr><td>3928864.0</td><td>434.7</td><td>List(1.0, 1.0, List(), List(3928864.0))</td><td>339.7970718564957</td></tr><tr><td>319504.0</td><td>281.0</td><td>List(1.0, 1.0, List(), List(319504.0))</td><td>203.37085497805197</td></tr><tr><td>485199.0</td><td>275.8</td><td>List(1.0, 1.0, List(), List(485199.0))</td><td>209.6337774922023</td></tr><tr><td>1381069.0</td><td>510.3</td><td>List(1.0, 1.0, List(), List(1381069.0))</td><td>243.49577931936597</td></tr><tr><td>852469.0</td><td>748.3</td><td>List(1.0, 1.0, List(), List(852469.0))</td><td>223.51581105852597</td></tr><tr><td>1015785.0</td><td>900.0</td><td>List(1.0, 1.0, List(), List(1015785.0))</td><td>229.6888123761335</td></tr><tr><td>105112.0</td><td>442.2</td><td>List(1.0, 1.0, List(), List(105112.0))</td><td>195.26728828229335</td></tr><tr><td>445830.0</td><td>220.1</td><td>List(1.0, 1.0, List(), List(445830.0))</td><td>208.14571209216257</td></tr><tr><td>663862.0</td><td>338.1</td><td>List(1.0, 1.0, List(), List(663862.0))</td><td>216.3868631323583</td></tr><tr><td>147612.0</td><td>342.7</td><td>List(1.0, 1.0, List(), List(147612.0))</td><td>196.8736988972871</td></tr><tr><td>124705.0</td><td>202.6</td><td>List(1.0, 1.0, List(), List(124705.0))</td><td>196.00786247475386</td></tr><tr><td>130282.0</td><td>205.1</td><td>List(1.0, 1.0, List(), List(130282.0))</td><td>196.2186613453379</td></tr><tr><td>658893.0</td><td>367.8</td><td>List(1.0, 1.0, List(), List(658893.0))</td><td>216.19904538304291</td></tr><tr><td>169854.0</td><td>208.0</td><td>List(1.0, 1.0, List(), List(169854.0))</td><td>197.71439971843276</td></tr><tr><td>128460.0</td><td>169.9</td><td>List(1.0, 1.0, List(), List(128460.0))</td><td>196.14979357732568</td></tr><tr><td>853382.0</td><td>182.5</td><td>List(1.0, 1.0, List(), List(853382.0))</td><td>223.55032053832574</td></tr><tr><td>102346.0</td><td>136.0</td><td>List(1.0, 1.0, List(), List(102346.0))</td><td>195.16273929967986</td></tr><tr><td>430332.0</td><td>269.1</td><td>List(1.0, 1.0, List(), List(430332.0))</td><td>207.5599202871938</td></tr><tr><td>105838.0</td><td>145.0</td><td>List(1.0, 1.0, List(), List(105838.0))</td><td>195.2947295553871</td></tr><tr><td>174110.0</td><td>172.0</td><td>List(1.0, 1.0, List(), List(174110.0))</td><td>197.87526756731307</td></tr><tr><td>188107.0</td><td>170.5</td><td>List(1.0, 1.0, List(), List(188107.0))</td><td>198.40432472914998</td></tr><tr><td>358699.0</td><td>156.0</td><td>List(1.0, 1.0, List(), List(358699.0))</td><td>204.85234354404443</td></tr><tr><td>456002.0</td><td>158.0</td><td>List(1.0, 1.0, List(), List(456002.0))</td><td>208.53019229865</td></tr><tr><td>350399.0</td><td>699.3</td><td>List(1.0, 1.0, List(), List(350399.0))</td><td>204.53862100041036</td></tr><tr><td>216282.0</td><td>178.7</td><td>List(1.0, 1.0, List(), List(216282.0))</td><td>199.46928047214877</td></tr><tr><td>2722389.0</td><t ...

# %% [markdown]
# ## Evaluate the Model
# #### Predicted vs. True label

# %%
from pyspark.ml.evaluation import RegressionEvaluator
evaluator = RegressionEvaluator(metricName="rmse")
RMSE = evaluator.evaluate(predictionsA)
print("ModelA: Root Mean Squared Error = " + str(RMSE))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ModelA: Root Mean Squared Error = 128.602026843
# </div>

# %%
predictionsB = modelB.transform(output)
RMSE = evaluator.evaluate(predictionsB)
print("ModelB: Root Mean Squared Error = " + str(RMSE))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ModelB: Root Mean Squared Error = 129.496300193
# </div>

# %% [markdown]
# # Linear Regression Plots

# %%
import numpy as np
from pandas import *
from ggplot import *

pop = output.rdd.map(lambda p: (p.features[0])).collect()
price = output.rdd.map(lambda p: (p.label)).collect()
predA = predictionsA.select("prediction").rdd.map(lambda r: r[0]).collect()
predB = predictionsB.select("prediction").rdd.map(lambda r: r[0]).collect()

pydf = DataFrame({'pop':pop,'price':price,'predA':predA, 'predB':predB})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## View the Python Pandas DataFrame (pydf)

# %%
pydf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>
#          pop       predA       predB  price
# 0     212247  199.316766  204.436404  162.9
# 1     188226  198.408823  203.917466  157.7
# 2     194675  198.652581  204.056787  122.5
# 3     200481  198.872036  204.182217  129.0
# 4    1537058  249.391835  233.056957  206.1
# 5     527972  211.250507  211.257168  178.1
# 6     197706  198.767147  204.122267  131.8
# 7     346997  204.410033  207.347475  685.7
# 8    3928864  339.797072  284.728337  434.7
# 9     319504  203.370855  206.753530  281.0
# 10    485199  209.633777  210.333122  275.8
# 11   1381069  243.495779  229.687049  510.3
# 12    852469  223.515811  218.267439  748.3
# 13   1015785  229.688812  221.795636  900.0
# 14    105112  195.267288  202.121913  442.2
# 15    445830  208.145712  209.482614  220.1
# 16    663862  216.386863  214.192868  338.1
# 17    147612  196.873699  203.040061  342.7
# 18    124705  196.007862  202.545190  202.6
# 19    130282  196.218661  202.665673  205.1
# 20    658893  216.199045  214.085520  367.8
# 21    169854  197.714400  203.520566  208.0
# 22    128460  196.149794  202.626311  169.9
# 23    853382  223.550321  218.287163  182.5
# 24    102346  195.162739  202.062157  136.0
# 25    430332  207.559920  209.147803  269.1
# 26    105838  195.294730  202.137597  145.0
# 27    174110  197.875268  203.612511  172.0
# 28    188107  198.404325  203.914895  170.5
# 29    358699  204.852344  207.600279  156.0
# ..       ...         ...         ...    ...
# 79    141003  196.623893  202.897284  107.2
# 80    281031  201.916656  205.922379   83.8
# 81    399682  206.401415  208.485656  145.1
# 82    160561  197.363144  203.319805  211.3
# 83    619360  214.704781  213.231469  289.4
# 84    161637  197.403814  203.343050  193.9
# 85    119104  195.796156  202.424189  162.7
# 86   1560297  250.270221  233.559001  204.9
# 87    179154  198.065920  203.721479  233.3
# 88    168586  197.666472  203.493173  159.5
# 89    173778  197.862719  203.605339  143.6
# 90    184281  198.259710  203.832240  149.2
# 91    656861  216.122240  214.041622  132.1
# 92    644014  215.636650  213.764082  186.4
# 93    120958  195.866234  202.464242  145.7
# 94    197254  198.750062  204.112502  144.4
# 95    912791  225.795856  219.570606  249.1
# 96    117585  195.738741  202.391373  133.3
# 97    320434  203.406007  206.773621  172.9
# 98   1281047  239.715158  227.526224  192.5
# 99    679036  216.960408  214.520680  138.4
# 100  2239558  275.944858  248.233416  200.3
# 101  1436697  245.598401  230.888809  184.7
# 102   190884  198.509289  203.974888  243.3
# 103   217853  199.528661  204.557513  212.5
# 104   450980  208.340371  209.593872  190.0
# 105   668342  216.556198  214.289652  352.4
# 106   212052  199.309395  204.432191  180.2
# 107   245691  200.580879  205.158911  226.2
# 108   599642  213.959482  212.805491  195.4
#
# [109 rows x 4 columns]
# </div>

# %% [markdown]
# ## ggplot figure
# Now that the Python Pandas DataFrame (pydf), use ggplot and display the scatterplot and the two regression models

# %%
p = ggplot(pydf, aes('pop','price')) + \
    geom_point(color='blue') + \
    geom_line(pydf, aes('pop','predA'), color='red') + \
    geom_line(pydf, aes('pop','predB'), color='green') + \
    scale_x_log10() + scale_y_log10()
display(p)
